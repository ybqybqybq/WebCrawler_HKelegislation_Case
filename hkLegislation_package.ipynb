# %%
import time
import os
import requests
import json

# %% [markdown]
# 获取json

# %%
def get_json():
    for range_page in [('1-100', 18), ('101-200', 32), ('201-300', 19), ('301-400', 28), ('401-500', 16),
                       ('501-600', 25), ('601-700', 6), ('1001-1100', 6),
                       ('1101-1200', 5)]:
        cookies = {
            'CLIENT_URL_FORWARD': 'UBIeSAUCHhxHERwTWFQDDVEFVFBHWQkFE1pXEERQHRc=',
            'TaJM6jvsmH6aaGI39F7o7inO': 'v1LMIxJQSDi2f',
            'CLIENT_CONFIG_RESULT_ATTRIBUTE': '%7B%22isOSSupported%22%3Atrue%2C%22isJvmVersionSupported%22%3Afalse%2C%22isBrowserSupported%22%3Atrue%2C%22isJvmSupported%22%3Afalse%2C%22isOSVersionSupported%22%3Atrue%2C%22isBrowserVersionSupported%22%3Atrue%7D',
            'CLIENT_CONFIG_ATTRIBUTE': '%7B%22branchCode%22%3A%2200%22%2C%22jvmVendor%22%3A%22%22%2C%22osVersion%22%3A%22Windows+10%22%2C%22jvmVersion%22%3A%22%22%2C%22browserVersion%22%3A%22116.0%22%2C%22isJavascriptEnabled%22%3Atrue%2C%22browserName%22%3A%22Chrome%22%2C%22userAgent%22%3A%22Mozilla%2F5.0+%28Windows+NT+10.0%3B+Win64%3B+x64%29+AppleWebKit%2F537.36+%28KHTML%2C+like+Gecko%29+Chrome%2F116.0.0.0+Safari%2F537.36+Edg%2F116.0.1938.81%22%2C%22applicationId%22%3A%22RA001%22%2C%22osName%22%3A%22Windows%22%2C%22isJvmEnabled%22%3Afalse%2C%22isCookieEnabled%22%3Atrue%7D',
            'CLIENT_REDIRECT_URL_ATTRIBUTE': 'https://www.elegislation.gov.hk/client-check',
            'fontSize': 'default',
            'clientCheckStatus': 'S',
            'uiLanguage': 'zh-CN',
            'JSTP2': '439D613F0BD922D927FB49FDE8D4137B',
            'TaJM6jvsmH6aaGE39F7o7inO': 'v1LMI1JQSDxFt',
            'JSWP2': 'A04C5974B77F42EF377649A86E3C9FF0',
        }

        headers = {
            # 'Cookie': 'CLIENT_URL_FORWARD=UBIeSAUCHhxHERwTWFQDDVEFVFBHWQkFE1pXEERQHRc=; TaJM6jvsmH6aaGI39F7o7inO=v1LMIxJQSDi2f; CLIENT_CONFIG_RESULT_ATTRIBUTE=%7B%22isOSSupported%22%3Atrue%2C%22isJvmVersionSupported%22%3Afalse%2C%22isBrowserSupported%22%3Atrue%2C%22isJvmSupported%22%3Afalse%2C%22isOSVersionSupported%22%3Atrue%2C%22isBrowserVersionSupported%22%3Atrue%7D; CLIENT_CONFIG_ATTRIBUTE=%7B%22branchCode%22%3A%2200%22%2C%22jvmVendor%22%3A%22%22%2C%22osVersion%22%3A%22Windows+10%22%2C%22jvmVersion%22%3A%22%22%2C%22browserVersion%22%3A%22116.0%22%2C%22isJavascriptEnabled%22%3Atrue%2C%22browserName%22%3A%22Chrome%22%2C%22userAgent%22%3A%22Mozilla%2F5.0+%28Windows+NT+10.0%3B+Win64%3B+x64%29+AppleWebKit%2F537.36+%28KHTML%2C+like+Gecko%29+Chrome%2F116.0.0.0+Safari%2F537.36+Edg%2F116.0.1938.81%22%2C%22applicationId%22%3A%22RA001%22%2C%22osName%22%3A%22Windows%22%2C%22isJvmEnabled%22%3Afalse%2C%22isCookieEnabled%22%3Atrue%7D; CLIENT_REDIRECT_URL_ATTRIBUTE=https://www.elegislation.gov.hk/client-check; fontSize=default; clientCheckStatus=S; uiLanguage=zh-CN; JSTP2=439D613F0BD922D927FB49FDE8D4137B; TaJM6jvsmH6aaGE39F7o7inO=v1LMI1JQSDxFt; JSWP2=A04C5974B77F42EF377649A86E3C9FF0',
            'Origin': 'https://www.elegislation.gov.hk',

            'Referer': 'https://www.elegislation.gov.hk/index/chapternumber?TYPE=1&TYPE=2&TYPE=3&LANGUAGE=E',

            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36 Edg/116.0.1938.81',

        }
        
        try:
            for page_no in range(range_page[1]):
                json_data = {
                    'gridId': 'CHAPTER_NO_INDEX_GRID',
                    'gridIndex': '0',
                    'gsId': 'CHAPTER_NO_INDEX_GRID',
                    'functionId': 'ECRS01',
                    'defaultSortColumn': '',
                    'defaultSortOrder': '',
                    'sortColumn': '',
                    'sortOrder': '',
                    'pageNo': f'{page_no}',
                    'pageSize': '20',
                    'template': '',
                    'pkFields': '',
                    'queryParams': [
                        'CAP_NO_FR=',
                        'CAP_NO_TO=',
                        'TYPE=1',
                        'TYPE=2',
                        'TYPE=3',
                        'TITLE=',
                        'STATUS=',
                        'LANGUAGE=E',
                        f'GROUPING={range_page[0]}',
                    ],
                    'dataItems': [],
                    'columns': [
                        'CAP_NO',
                        'TITLE',
                        'PDF_RTF',
                        'PDF_RTF',
                        'PDF_RTF',
                    ],
                    'labels': [
                        '章 / 文件 号',
                        '章 / 文件 标题',
                        '双语',
                        '英文',
                        '中文',
                    ],
                    'dataType': [],
                    'link': [],
                    'lookup': [],
                    'sortable': [
                        False,
                        False,
                        False,
                        False,
                        False,
                    ],
                    'alignment': [
                        'left',
                        'left',
                        'center',
                        'center',
                        'center',
                    ],
                    'format': [],
                    'sortColRefName': [],
                    'columnGenerator': [],
                    'csrfToken': 'XqCs0QoTQpAT0lgnTNW8of2EC++HyVenddVC62qpKCg0bcBoqS0bGBwSGcQD9EPEB1JEC5tSp3fjH2Yfr9w+Hg==',
                    'requiredRights': [],
                    'columnWidths': [
                        '15%',
                        '*',
                        '10%',
                        '10%',
                        '10%',
                    ],
                    'minColumnWidths': [],
                    'criteria': {},
                    'footable': True,
                    'queryId': 'CHAPTER_NO_INDEX_GRID_QRY',
                    'screenId': 'ECRS0105',
                    'gridBd': 'hk.gov.doj.hkel.grid.ecr.LCRS1005GridBd',
                    'groupColumn': '',
                    'queryOrder': '',
                    'checkBoxKey': '',
                    'namespace': 'hk.gov.doj.hkel.bd.ecr.ECRS0105Bd',
                    'checkBoxKeyFormat': '',
                    'controls': [
                        'generateCapNo',
                        'generateTitle',
                        'generatePDFB',
                        'generatePDFE',
                        'generatePDFC',
                    ],
                    'MODE': '1',
                }

                response = requests.post('https://www.elegislation.gov.hk/grid', cookies=cookies, headers=headers,
                                         json=json_data)
                res_json = json.loads(response.text)
                time.sleep(0.5)
                try:
                    for i in range(21):
                        code = res_json['rowData'][i][0]
                        name = res_json['rowData'][i][1]
                        list.append((code, name))
                        # print(f'{range_page[0]} ：第{page_no + 1}页 第{i}个')
                except:
                    pass
        except json.decoder.JSONDecodeError:
            pass
    return list

# %% [markdown]
# pdf下载

# %%
def download_pdf_eng(code, name, count=0):
    if count>=3:
        download_pdf_eng_2(code, name)
    cookies = {
        'CLIENT_URL_FORWARD': 'UBIeSAUCHhxHERwTWFQDDVEFVFBHWQkFE1pXEERQHRc=',
        'TaJM6jvsmH6aaGI39F7o7inO': 'v1LMIxJQSDi2f',
        'CLIENT_CONFIG_RESULT_ATTRIBUTE': '%7B%22isOSSupported%22%3Atrue%2C%22isJvmVersionSupported%22%3Afalse%2C%22isBrowserSupported%22%3Atrue%2C%22isJvmSupported%22%3Afalse%2C%22isOSVersionSupported%22%3Atrue%2C%22isBrowserVersionSupported%22%3Atrue%7D',
        'CLIENT_CONFIG_ATTRIBUTE': '%7B%22branchCode%22%3A%2200%22%2C%22jvmVendor%22%3A%22%22%2C%22osVersion%22%3A%22Windows+10%22%2C%22jvmVersion%22%3A%22%22%2C%22browserVersion%22%3A%22116.0%22%2C%22isJavascriptEnabled%22%3Atrue%2C%22browserName%22%3A%22Chrome%22%2C%22userAgent%22%3A%22Mozilla%2F5.0+%28Windows+NT+10.0%3B+Win64%3B+x64%29+AppleWebKit%2F537.36+%28KHTML%2C+like+Gecko%29+Chrome%2F116.0.0.0+Safari%2F537.36+Edg%2F116.0.1938.81%22%2C%22applicationId%22%3A%22RA001%22%2C%22osName%22%3A%22Windows%22%2C%22isJvmEnabled%22%3Afalse%2C%22isCookieEnabled%22%3Atrue%7D',
        'CLIENT_REDIRECT_URL_ATTRIBUTE': 'https://www.elegislation.gov.hk/client-check',
        'fontSize': 'default',
        'clientCheckStatus': 'S',
        'uiLanguage': 'zh-CN',
        'JSTP2': '439D613F0BD922D927FB49FDE8D4137B',
        'TaJM6jvsmH6aaGE39F7o7inO': 'v1LMI1JQSDxFt',
        'JSWP2': 'A04C5974B77F42EF377649A86E3C9FF0',
    }

    headers = {
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
        'Accept-Language': 'zh-CN,zh;q=0.9,en;q=0.8,en-GB;q=0.7,en-US;q=0.6',
        'Cache-Control': 'no-cache',
        'Connection': 'keep-alive',
        # 'Cookie': 'CLIENT_URL_FORWARD=UBIeSAUCHhxHERwTWFQDDVEFVFBHWQkFE1pXEERQHRc=; TaJM6jvsmH6aaGI39F7o7inO=v1LMIxJQSDi2f; CLIENT_CONFIG_RESULT_ATTRIBUTE=%7B%22isOSSupported%22%3Atrue%2C%22isJvmVersionSupported%22%3Afalse%2C%22isBrowserSupported%22%3Atrue%2C%22isJvmSupported%22%3Afalse%2C%22isOSVersionSupported%22%3Atrue%2C%22isBrowserVersionSupported%22%3Atrue%7D; CLIENT_CONFIG_ATTRIBUTE=%7B%22branchCode%22%3A%2200%22%2C%22jvmVendor%22%3A%22%22%2C%22osVersion%22%3A%22Windows+10%22%2C%22jvmVersion%22%3A%22%22%2C%22browserVersion%22%3A%22116.0%22%2C%22isJavascriptEnabled%22%3Atrue%2C%22browserName%22%3A%22Chrome%22%2C%22userAgent%22%3A%22Mozilla%2F5.0+%28Windows+NT+10.0%3B+Win64%3B+x64%29+AppleWebKit%2F537.36+%28KHTML%2C+like+Gecko%29+Chrome%2F116.0.0.0+Safari%2F537.36+Edg%2F116.0.1938.81%22%2C%22applicationId%22%3A%22RA001%22%2C%22osName%22%3A%22Windows%22%2C%22isJvmEnabled%22%3Afalse%2C%22isCookieEnabled%22%3Atrue%7D; CLIENT_REDIRECT_URL_ATTRIBUTE=https://www.elegislation.gov.hk/client-check; fontSize=default; clientCheckStatus=S; uiLanguage=zh-CN; JSTP2=439D613F0BD922D927FB49FDE8D4137B; TaJM6jvsmH6aaGE39F7o7inO=v1LMI1JQSDxFt; JSWP2=A04C5974B77F42EF377649A86E3C9FF0',
        'Pragma': 'no-cache',
        'Referer': 'https://www.elegislation.gov.hk/index/chapternumber?TYPE=1&TYPE=2&TYPE=3&LANGUAGE=E',
        'Sec-Fetch-Dest': 'document',
        'Sec-Fetch-Mode': 'navigate',
        'Sec-Fetch-Site': 'same-origin',
        'Sec-Fetch-User': '?1',
        'Upgrade-Insecure-Requests': '1',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36 Edg/116.0.1938.81',
        'sec-ch-ua': '"Chromium";v="116", "Not)A;Brand";v="24", "Microsoft Edge";v="116"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
    }

    params = {
        'FROMCAPINDEX': 'Y',
    }

    response = requests.get(
        f'https://www.elegislation.gov.hk/hk/cap{code}!en.pdf',  #
        params=params,
        cookies=cookies,
        headers=headers,
    )

    minimum_file_size = 40 * 1024
    file_path = f'D:\\pdf_en\\{name}.pdf'
    with open(file_path, mode='wb') as f:
        f.write(response.content)

    file_size = os.path.getsize(file_path)
    if file_size < minimum_file_size:
        # 文件大小小于最小值，重新下载
        print("下载的文件大小不够，重新下载")
        download_pdf_eng(code, name, count +1)
        # 执行重新下载的操作...
    time.sleep(0.5)


    cookies = {
        'CLIENT_URL_FORWARD': 'UBIeSAUCHhxHERwTWFQDDVEFVFBHWQkFE1pXEERQHRc=',
        'TaJM6jvsmH6aaGI39F7o7inO': 'v1LMIxJQSDi2f',
        'CLIENT_CONFIG_RESULT_ATTRIBUTE': '%7B%22isOSSupported%22%3Atrue%2C%22isJvmVersionSupported%22%3Afalse%2C%22isBrowserSupported%22%3Atrue%2C%22isJvmSupported%22%3Afalse%2C%22isOSVersionSupported%22%3Atrue%2C%22isBrowserVersionSupported%22%3Atrue%7D',
        'CLIENT_CONFIG_ATTRIBUTE': '%7B%22branchCode%22%3A%2200%22%2C%22jvmVendor%22%3A%22%22%2C%22osVersion%22%3A%22Windows+10%22%2C%22jvmVersion%22%3A%22%22%2C%22browserVersion%22%3A%22116.0%22%2C%22isJavascriptEnabled%22%3Atrue%2C%22browserName%22%3A%22Chrome%22%2C%22userAgent%22%3A%22Mozilla%2F5.0+%28Windows+NT+10.0%3B+Win64%3B+x64%29+AppleWebKit%2F537.36+%28KHTML%2C+like+Gecko%29+Chrome%2F116.0.0.0+Safari%2F537.36+Edg%2F116.0.1938.81%22%2C%22applicationId%22%3A%22RA001%22%2C%22osName%22%3A%22Windows%22%2C%22isJvmEnabled%22%3Afalse%2C%22isCookieEnabled%22%3Atrue%7D',
        'CLIENT_REDIRECT_URL_ATTRIBUTE': 'https://www.elegislation.gov.hk/client-check',
        'fontSize': 'default',
        'clientCheckStatus': 'S',
        'uiLanguage': 'zh-CN',
        'JSTP2': '439D613F0BD922D927FB49FDE8D4137B',
        'TaJM6jvsmH6aaGE39F7o7inO': 'v1LMI1JQSDxFt',
        'JSWP2': 'A04C5974B77F42EF377649A86E3C9FF0',
    }

    headers = {
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
        'Accept-Language': 'zh-CN,zh;q=0.9,en;q=0.8,en-GB;q=0.7,en-US;q=0.6',
        'Cache-Control': 'no-cache',
        'Connection': 'keep-alive',
        # 'Cookie': 'CLIENT_URL_FORWARD=UBIeSAUCHhxHERwTWFQDDVEFVFBHWQkFE1pXEERQHRc=; TaJM6jvsmH6aaGI39F7o7inO=v1LMIxJQSDi2f; CLIENT_CONFIG_RESULT_ATTRIBUTE=%7B%22isOSSupported%22%3Atrue%2C%22isJvmVersionSupported%22%3Afalse%2C%22isBrowserSupported%22%3Atrue%2C%22isJvmSupported%22%3Afalse%2C%22isOSVersionSupported%22%3Atrue%2C%22isBrowserVersionSupported%22%3Atrue%7D; CLIENT_CONFIG_ATTRIBUTE=%7B%22branchCode%22%3A%2200%22%2C%22jvmVendor%22%3A%22%22%2C%22osVersion%22%3A%22Windows+10%22%2C%22jvmVersion%22%3A%22%22%2C%22browserVersion%22%3A%22116.0%22%2C%22isJavascriptEnabled%22%3Atrue%2C%22browserName%22%3A%22Chrome%22%2C%22userAgent%22%3A%22Mozilla%2F5.0+%28Windows+NT+10.0%3B+Win64%3B+x64%29+AppleWebKit%2F537.36+%28KHTML%2C+like+Gecko%29+Chrome%2F116.0.0.0+Safari%2F537.36+Edg%2F116.0.1938.81%22%2C%22applicationId%22%3A%22RA001%22%2C%22osName%22%3A%22Windows%22%2C%22isJvmEnabled%22%3Afalse%2C%22isCookieEnabled%22%3Atrue%7D; CLIENT_REDIRECT_URL_ATTRIBUTE=https://www.elegislation.gov.hk/client-check; fontSize=default; clientCheckStatus=S; uiLanguage=zh-CN; JSTP2=439D613F0BD922D927FB49FDE8D4137B; TaJM6jvsmH6aaGE39F7o7inO=v1LMI1JQSDxFt; JSWP2=A04C5974B77F42EF377649A86E3C9FF0',
        'Pragma': 'no-cache',
        'Referer': 'https://www.elegislation.gov.hk/index/chapternumber?TYPE=1&TYPE=2&TYPE=3&LANGUAGE=E',
        'Sec-Fetch-Dest': 'document',
        'Sec-Fetch-Mode': 'navigate',
        'Sec-Fetch-Site': 'same-origin',
        'Sec-Fetch-User': '?1',
        'Upgrade-Insecure-Requests': '1',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36 Edg/116.0.1938.81',
        'sec-ch-ua': '"Chromium";v="116", "Not)A;Brand";v="24", "Microsoft Edge";v="116"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
    }

    params = {
        'FROMCAPINDEX': 'Y',
    }

    response = requests.get(
        f'https://www.elegislation.gov.hk/hk/cap{code}!en-zh-Hant-HK.pdf',  # 双语
        params=params,
        cookies=cookies,
        headers=headers,
    )
    file_path = f'D:\\pdf\\{name}.pdf'
    with open(file_path, mode='wb') as f:
        f.write(response.content)

    minimum_file_size = 40 * 1024

    file_size = os.path.getsize(file_path)
    if file_size < minimum_file_size:
        # 文件大小小于最小值，重新下载
        print(f"{code},{name}下载的文件大小不够")

        # 执行重新下载的操作...
    time.sleep(0.5)



    cookies = {
        'CLIENT_URL_FORWARD': 'UBIeSAUCHhxHERwTWFQDDVEFVFBHWQkFE1pXEERQHRc=',
        'TaJM6jvsmH6aaGI39F7o7inO': 'v1LMIxJQSDi2f',
        'CLIENT_CONFIG_RESULT_ATTRIBUTE': '%7B%22isOSSupported%22%3Atrue%2C%22isJvmVersionSupported%22%3Afalse%2C%22isBrowserSupported%22%3Atrue%2C%22isJvmSupported%22%3Afalse%2C%22isOSVersionSupported%22%3Atrue%2C%22isBrowserVersionSupported%22%3Atrue%7D',
        'CLIENT_CONFIG_ATTRIBUTE': '%7B%22branchCode%22%3A%2200%22%2C%22jvmVendor%22%3A%22%22%2C%22osVersion%22%3A%22Windows+10%22%2C%22jvmVersion%22%3A%22%22%2C%22browserVersion%22%3A%22116.0%22%2C%22isJavascriptEnabled%22%3Atrue%2C%22browserName%22%3A%22Chrome%22%2C%22userAgent%22%3A%22Mozilla%2F5.0+%28Windows+NT+10.0%3B+Win64%3B+x64%29+AppleWebKit%2F537.36+%28KHTML%2C+like+Gecko%29+Chrome%2F116.0.0.0+Safari%2F537.36+Edg%2F116.0.1938.81%22%2C%22applicationId%22%3A%22RA001%22%2C%22osName%22%3A%22Windows%22%2C%22isJvmEnabled%22%3Afalse%2C%22isCookieEnabled%22%3Atrue%7D',
        'CLIENT_REDIRECT_URL_ATTRIBUTE': 'https://www.elegislation.gov.hk/client-check',
        'fontSize': 'default',
        'clientCheckStatus': 'S',
        'uiLanguage': 'zh-CN',
        'JSTP2': '439D613F0BD922D927FB49FDE8D4137B',
        'TaJM6jvsmH6aaGE39F7o7inO': 'v1LMI1JQSDxFt',
        'JSWP2': 'A04C5974B77F42EF377649A86E3C9FF0',
    }

    headers = {
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
        'Accept-Language': 'zh-CN,zh;q=0.9,en;q=0.8,en-GB;q=0.7,en-US;q=0.6',
        'Cache-Control': 'no-cache',
        'Connection': 'keep-alive',
        # 'Cookie': 'CLIENT_URL_FORWARD=UBIeSAUCHhxHERwTWFQDDVEFVFBHWQkFE1pXEERQHRc=; TaJM6jvsmH6aaGI39F7o7inO=v1LMIxJQSDi2f; CLIENT_CONFIG_RESULT_ATTRIBUTE=%7B%22isOSSupported%22%3Atrue%2C%22isJvmVersionSupported%22%3Afalse%2C%22isBrowserSupported%22%3Atrue%2C%22isJvmSupported%22%3Afalse%2C%22isOSVersionSupported%22%3Atrue%2C%22isBrowserVersionSupported%22%3Atrue%7D; CLIENT_CONFIG_ATTRIBUTE=%7B%22branchCode%22%3A%2200%22%2C%22jvmVendor%22%3A%22%22%2C%22osVersion%22%3A%22Windows+10%22%2C%22jvmVersion%22%3A%22%22%2C%22browserVersion%22%3A%22116.0%22%2C%22isJavascriptEnabled%22%3Atrue%2C%22browserName%22%3A%22Chrome%22%2C%22userAgent%22%3A%22Mozilla%2F5.0+%28Windows+NT+10.0%3B+Win64%3B+x64%29+AppleWebKit%2F537.36+%28KHTML%2C+like+Gecko%29+Chrome%2F116.0.0.0+Safari%2F537.36+Edg%2F116.0.1938.81%22%2C%22applicationId%22%3A%22RA001%22%2C%22osName%22%3A%22Windows%22%2C%22isJvmEnabled%22%3Afalse%2C%22isCookieEnabled%22%3Atrue%7D; CLIENT_REDIRECT_URL_ATTRIBUTE=https://www.elegislation.gov.hk/client-check; fontSize=default; clientCheckStatus=S; uiLanguage=zh-CN; JSTP2=439D613F0BD922D927FB49FDE8D4137B; TaJM6jvsmH6aaGE39F7o7inO=v1LMI1JQSDxFt; JSWP2=A04C5974B77F42EF377649A86E3C9FF0',
        'Pragma': 'no-cache',
        'Referer': 'https://www.elegislation.gov.hk/index/chapternumber?TYPE=1&TYPE=2&TYPE=3&LANGUAGE=C',
        'Sec-Fetch-Dest': 'document',
        'Sec-Fetch-Mode': 'navigate',
        'Sec-Fetch-Site': 'same-origin',
        'Sec-Fetch-User': '?1',
        'Upgrade-Insecure-Requests': '1',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36 Edg/116.0.1938.81',
        'sec-ch-ua': '"Chromium";v="116", "Not)A;Brand";v="24", "Microsoft Edge";v="116"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
    }

    params = {
        'FROMCAPINDEX': 'Y',
    }

    response = requests.get(
        f'https://www.elegislation.gov.hk/hk/cap{code}!en-Hant-HK.pdf',  # 双语
        params=params,
        cookies=cookies,
        headers=headers,
    )
    file_path = f'D:\\pdf\\{name}.pdf'
    with open(file_path, mode='wb') as f:
        f.write(response.content)

    minimum_file_size = 40 * 1024

    file_size = os.path.getsize(file_path)
    if file_size < minimum_file_size:
        # 文件大小小于最小值，重新下载
        print(f"{code},{name}下载的文件大小不够")

        # 执行重新下载的操作...
    time.sleep(0.5)

def download_pdf_bilingual(code, name, count =0):
    if count > 3:
        download_pdf_shuangyu_2(code, name)
    cookies = {
        'CLIENT_URL_FORWARD': 'UBIeSAUCHhxHERwTWFQDDVEFVFBHWQkFE1pXEERQHRc=',
        'TaJM6jvsmH6aaGI39F7o7inO': 'v1LMIxJQSDi2f',
        'CLIENT_CONFIG_RESULT_ATTRIBUTE': '%7B%22isOSSupported%22%3Atrue%2C%22isJvmVersionSupported%22%3Afalse%2C%22isBrowserSupported%22%3Atrue%2C%22isJvmSupported%22%3Afalse%2C%22isOSVersionSupported%22%3Atrue%2C%22isBrowserVersionSupported%22%3Atrue%7D',
        'CLIENT_CONFIG_ATTRIBUTE': '%7B%22branchCode%22%3A%2200%22%2C%22jvmVendor%22%3A%22%22%2C%22osVersion%22%3A%22Windows+10%22%2C%22jvmVersion%22%3A%22%22%2C%22browserVersion%22%3A%22116.0%22%2C%22isJavascriptEnabled%22%3Atrue%2C%22browserName%22%3A%22Chrome%22%2C%22userAgent%22%3A%22Mozilla%2F5.0+%28Windows+NT+10.0%3B+Win64%3B+x64%29+AppleWebKit%2F537.36+%28KHTML%2C+like+Gecko%29+Chrome%2F116.0.0.0+Safari%2F537.36+Edg%2F116.0.1938.81%22%2C%22applicationId%22%3A%22RA001%22%2C%22osName%22%3A%22Windows%22%2C%22isJvmEnabled%22%3Afalse%2C%22isCookieEnabled%22%3Atrue%7D',
        'CLIENT_REDIRECT_URL_ATTRIBUTE': 'https://www.elegislation.gov.hk/client-check',
        'fontSize': 'default',
        'clientCheckStatus': 'S',
        'uiLanguage': 'zh-CN',
        'JSTP2': '439D613F0BD922D927FB49FDE8D4137B',
        'TaJM6jvsmH6aaGE39F7o7inO': 'v1LMI1JQSDxFt',
        'JSWP2': 'A04C5974B77F42EF377649A86E3C9FF0',
    }

    headers = {
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
        'Accept-Language': 'zh-CN,zh;q=0.9,en;q=0.8,en-GB;q=0.7,en-US;q=0.6',
        'Cache-Control': 'no-cache',
        'Connection': 'keep-alive',
        # 'Cookie': 'CLIENT_URL_FORWARD=UBIeSAUCHhxHERwTWFQDDVEFVFBHWQkFE1pXEERQHRc=; TaJM6jvsmH6aaGI39F7o7inO=v1LMIxJQSDi2f; CLIENT_CONFIG_RESULT_ATTRIBUTE=%7B%22isOSSupported%22%3Atrue%2C%22isJvmVersionSupported%22%3Afalse%2C%22isBrowserSupported%22%3Atrue%2C%22isJvmSupported%22%3Afalse%2C%22isOSVersionSupported%22%3Atrue%2C%22isBrowserVersionSupported%22%3Atrue%7D; CLIENT_CONFIG_ATTRIBUTE=%7B%22branchCode%22%3A%2200%22%2C%22jvmVendor%22%3A%22%22%2C%22osVersion%22%3A%22Windows+10%22%2C%22jvmVersion%22%3A%22%22%2C%22browserVersion%22%3A%22116.0%22%2C%22isJavascriptEnabled%22%3Atrue%2C%22browserName%22%3A%22Chrome%22%2C%22userAgent%22%3A%22Mozilla%2F5.0+%28Windows+NT+10.0%3B+Win64%3B+x64%29+AppleWebKit%2F537.36+%28KHTML%2C+like+Gecko%29+Chrome%2F116.0.0.0+Safari%2F537.36+Edg%2F116.0.1938.81%22%2C%22applicationId%22%3A%22RA001%22%2C%22osName%22%3A%22Windows%22%2C%22isJvmEnabled%22%3Afalse%2C%22isCookieEnabled%22%3Atrue%7D; CLIENT_REDIRECT_URL_ATTRIBUTE=https://www.elegislation.gov.hk/client-check; fontSize=default; clientCheckStatus=S; uiLanguage=zh-CN; JSTP2=439D613F0BD922D927FB49FDE8D4137B; TaJM6jvsmH6aaGE39F7o7inO=v1LMI1JQSDxFt; JSWP2=A04C5974B77F42EF377649A86E3C9FF0',
        'Pragma': 'no-cache',
        'Referer': 'https://www.elegislation.gov.hk/index/chapternumber?TYPE=1&TYPE=2&TYPE=3&LANGUAGE=C',
        'Sec-Fetch-Dest': 'document',
        'Sec-Fetch-Mode': 'navigate',
        'Sec-Fetch-Site': 'same-origin',
        'Sec-Fetch-User': '?1',
        'Upgrade-Insecure-Requests': '1',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36 Edg/116.0.1938.81',
        'sec-ch-ua': '"Chromium";v="116", "Not)A;Brand";v="24", "Microsoft Edge";v="116"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
    }

    params = {
        'FROMCAPINDEX': 'Y',
    }

    response = requests.get(
        f'https://www.elegislation.gov.hk/hk/cap{code}!en-sc.assist.pdf',  # 双语
        params=params,
        cookies=cookies,
        headers=headers,
    )
    file_path = f'D:\\pdf\\{name}.pdf'
    with open(file_path, mode='wb') as f:
        f.write(response.content)

    minimum_file_size = 40 * 1024

    file_size = os.path.getsize(file_path)
    if file_size < minimum_file_size:
        # 文件大小小于最小值，重新下载
        print("下载的文件大小不够，重新下载")
        download_pdf_shuangyu(code, name, count +1)
        # 执行重新下载的操作...
    time.sleep(0.5)

# %%
if __name__ == '__main__':
    list = []
    list = get_json()
    print(list)
    for i in range(len(list)):
        download_pdf_bilingual(list[i][0], list[i][1])
        download_pdf_eng(list[i][0], list[i][1])
        print(f'第{i + 1}个文件已下载')
